# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **David Baksh**
# Musician

# %% [markdown]
# *I am interested in data science due to my curiosity based on how our data is collected and used. Can we be more than commodities? Our data is being used for profit, we should be compensated everytime our information is collected because without us there is no data to collect in order to sell*

# %% [markdown]
# ### My code in the next cell will determine the average goals per game (GPG) scored by Alan Shearer in the Premier League. Goals/Games= GPG

# %%
260/441
# Out:
# 0.5895691609977324

# %% [markdown]
# ### [**Alan Shearer**](https://www.transfermarkt.com/alan-shearer/leistungsdaten/spieler/3110)
#
# ![image.png](attachment:image.png)
#
# |**GOALS**|**GAMES**|**GPG Average**|
# |:-------:|:-------:|:-------------:|
# |260      |441      |0.59
